# %%
import os
import pandas as pd
import numpy as np
from google.colab import drive
from google.colab import files
import random

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_data = pd.read_csv('/content/drive/MyDrive/Multilingual_Datasets/merged_dataset_train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/Multilingual_Datasets/merged_dataset_test.csv')

# %%
train_reduced = train_data.iloc[:34985,:]

# %%
#count number of labels
fake_count = 0
real_count = 0

for i in range(0, len(train_data)):
  if train_data['Label'][i] == 0:
    fake_count += 1
  else:
    real_count += 1

# %%
print(fake_count)
print(real_count)
# Out:
# 39952
# 7580
