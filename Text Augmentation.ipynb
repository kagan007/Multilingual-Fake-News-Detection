# %%
import os
import pandas as pd
import numpy as np
from google.colab import drive
from google.colab import files
import random

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_data = pd.read_csv('/content/drive/MyDrive/Multilingual_Datasets/train_dataframe.csv')
test_data = pd.read_csv('/content/drive/MyDrive/Multilingual_Datasets/test_dataframe.csv')
